# %% [markdown]
# # Qualitative Evaluation

# %% [markdown]
# ## Query Set
#
# | Query | Easy (Keyword-based) | Medium (Semantic-based) | Complex |
# |----------|----------|----------|----------|
# | 1 | fantasy brandon sanderson | fantasy novels with epic battles | stories similar to mistborn |
# | 2 | programming python beginner | textbook teaching introductory python | how should I learn python as a beginner |
# | 3 | italian cookbook | traditional pasta recipes from italy | recipes with regional italian cuisine |
# | 4 | travel paris france budget | travelling to paris france on a budget | how to do paris cheap |
# | 5 | american biographies | great past americans | books about presidents |
# | 6 | children's books about rocks | books for kids learning geology | how to teach grade 1 earth science |
# | 7 | landscape design plants | best locations for plants | how should I plant for my zone |
# | 8 | knitting crochet guide | easy guide to using wool | what are the various patterns for knitting |
# | 9 | start business | running a store successfully  | how to beat your competitors |
# | 10 | personal finance debt free| how to get out of debt | resources for getting your money in order |

# %% [markdown]
# ## Keyword Search

# %% [markdown]
# ## Semantic Search
