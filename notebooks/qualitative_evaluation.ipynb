# %% [markdown]
# # Qualitative Evaluation

# %% [markdown]
# ## Query Set
#
# | Query | Easy (Keyword-based) | Medium (Semantic-based) | Complex |
# |----------|----------|----------|----------|
# | 1 | Add Query     | Add Query     | Add Query     |
# | 2 | Add Query     | Add Query     | Add Query     |
# | 3 | Add Query     | Add Query     | Add Query     |
# | 4 | Add Query     | Add Query     | Add Query     |
# | 5 | Add Query     | Add Query     | Add Query     |
# | 6 | Add Query     | Add Query     | Add Query     |
# | 7 | Add Query     | Add Query     | Add Query     |
# | 8 | Add Query     | Add Query     | Add Query     |
# | 9 | Add Query     | Add Query     | Add Query     |
# | 10 | Add Query     | Add Query     | Add Query     |

# %% [markdown]
# ## Keyword Search

# %% [markdown]
# ## Semantic Search
